# %% [markdown]
# # Explore FIRMS data — India
# Load raw FIRMS pulls, plot on a map, sanity-check coverage before building features.

# %%
import pandas as pd
from src.utils.config import DATA_RAW

df = pd.read_csv(DATA_RAW / 'firms' / 'firms_latest.csv')
df.head()
